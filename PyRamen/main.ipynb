# %%
# -*- coding: UTF-8 -*-
"""PyRamen Homework Starter."""
# Out:
# 'PyRamen Homework Starter.'

# %%
# @TODO: Import libraries
import pandas as pd
import numpy as np

# %%
menudf = pd.read_csv('menu_data.csv')
salesdf = pd.read_csv('sales_data.csv')

# %%
menudf.head()
# Out:
#                            item    category  \
# 0                       edamame  appetizers
# 1                   house salad  appetizers
# 2       cucumber sunomono salad  appetizers
# 3  hiyashi wakame seaweed salad  appetizers
# 4                 agedashi tofu  appetizers
#
#                                          description  price  cost
# 0                   boiled soybeans, maldon sea salt    4.0     1
# 1  mixed greens, cherry tomatoes, cucumber, house...    4.0     2
# 2  cucumber, ponzu dressing, pickled ginger sprou...    5.0     2
# 3  sweet soy-marinated wakame seaweed threads, pi...    5.0     2
# 4  tempura battered tofu, katsuobushi, tsuyu brot...    5.0     2

# %%
menudf.shape
# Out:
# (32, 5)

# %%
salesdf.head()
# Out:
#    Line_Item_ID        Date  Credit_Card_Number  Quantity  \
# 0             1  01-01-2017    7437926611570799         1
# 1             2  01-01-2017    7437926611570799         1
# 2             3  01-01-2017    8421920068932819         3
# 3             4  01-01-2017    8421920068932819         3
# 4             5  01-01-2017    4787310681569648         1
#
#               Menu_Item
# 0      spicy miso ramen
# 1      spicy miso ramen
# 2     tori paitan ramen
# 3     tori paitan ramen
# 4  truffle butter ramen

# %%
salesdf.shape
# Out:
# (74124, 5)

# %%
#loop over rows and append each row to menu list
menu = []

# Iterate over each row in menudf
for index, rows in menudf.iterrows(): 
    # Create list for the current row 
     menurows=[rows.item, rows.category, rows.description, rows.price, rows.cost] 
      
    # append the list to the final list 
     menu.append(menurows)

# %%
sales = []
for index, rows in salesdf.iterrows():
    salesrows = [rows.Line_Item_ID, rows.Date, rows.Credit_Card_Number, rows.Quantity, rows.Menu_Item]
    sales.append(salesrows)

# %%
# Rename column titles to combine csv's in a moment.
menudf = menudf.rename({'item' : 'Menu_Item'}, axis = 'columns')
menudf.head()
# Out:
#                       Menu_Item    category  \
# 0                       edamame  appetizers
# 1                   house salad  appetizers
# 2       cucumber sunomono salad  appetizers
# 3  hiyashi wakame seaweed salad  appetizers
# 4                 agedashi tofu  appetizers
#
#                                          description  price  cost
# 0                   boiled soybeans, maldon sea salt    4.0     1
# 1  mixed greens, cherry tomatoes, cucumber, house...    4.0     2
# 2  cucumber, ponzu dressing, pickled ginger sprou...    5.0     2
# 3  sweet soy-marinated wakame seaweed threads, pi...    5.0     2
# 4  tempura battered tofu, katsuobushi, tsuyu brot...    5.0     2

# %%
combineddf = pd.merge(menudf, salesdf, on='Menu_Item', how='inner')

# %%
combineddf.head(50)
# Out:
#        Menu_Item category                                        description  \
# 0   nagomi shoyu   entree  shoyu seasoned clear double stock (organic chi...
# 1   nagomi shoyu   entree  shoyu seasoned clear double stock (organic chi...
# 2   nagomi shoyu   entree  shoyu seasoned clear double stock (organic chi...
# 3   nagomi shoyu   entree  shoyu seasoned clear double stock (organic chi...
# 4   nagomi shoyu   entree  shoyu seasoned clear double stock (organic chi...
# 5   nagomi shoyu   entree  shoyu seasoned clear double stock (organic chi...
# 6   nagomi shoyu   entree  shoyu seasoned clear double stock (organic chi...
# 7   nagomi shoyu   entree  shoyu seasoned clear double stock (organic chi...
# 8   nagomi shoyu   entree  shoyu seasoned clear double stock (organic chi...
# 9   nagomi shoyu   entree  shoyu seasoned clear double stock (organic chi...
# 10  nagomi shoyu   entree  shoyu seasoned clear double stock (organic chi...
# ...

# %%
   # Line_Item_ID,Date,Credit_Card_Number,Quantity,Menu_Item
    # @TODO: Initialize sales data variables
Line_Item_ID = 0
Date = 0
Credit_Card_number = 0
Quantity = 0
Menu_Item = 0

# %%
    # @TODO:
    # If the item value not in the report, add it as a new entry with initialized metrics
    # Naming convention allows the keys to be ordered in logical fashion, count, revenue, cost, profit

# %%
        # Item,Category,Description,Price,Cost
        # @TODO: Initialize menu data variables
Category = 0
Description = 0
Price = 0
COst = 0

# %%
        # @TODO: Calculate profit of each item in the menu data
dfpivot = pd.pivot_table(combineddf, values = ['price', 'cost'], index=['Menu_Item'], aggfunc=np.sum)
dfpivot
# Out:
#                                                  cost    price
# Menu_Item
# burnt garlic tonkotsu ramen                     40620  94780.0
# miso crab ramen                                 39324  78648.0
# nagomi shoyu                                    33300  73260.0
# shio ramen                                      33720  74184.0
# soft-shell miso crab ramen                      47194  94388.0
# spicy miso ramen                                34010  81624.0
# tonkotsu ramen                                  40800  88400.0
# tori paitan ramen                               40908  88634.0
# truffle butter ramen                            47082  94164.0
# vegetarian curry + king trumpet mushroom ramen  46802  86918.0
# vegetarian spicy miso                           34110  81864.0

# %%
dfpivot['Profit'] = (dfpivot['price'] - dfpivot['cost'])
dfpivot
# Out:
#                                                  cost    price   Profit
# Menu_Item
# burnt garlic tonkotsu ramen                     40620  94780.0  54160.0
# miso crab ramen                                 39324  78648.0  39324.0
# nagomi shoyu                                    33300  73260.0  39960.0
# shio ramen                                      33720  74184.0  40464.0
# soft-shell miso crab ramen                      47194  94388.0  47194.0
# spicy miso ramen                                34010  81624.0  47614.0
# tonkotsu ramen                                  40800  88400.0  47600.0
# tori paitan ramen                               40908  88634.0  47726.0
# truffle butter ramen                            47082  94164.0  47082.0
# vegetarian curry + king trumpet mushroom ramen  46802  86918.0  40116.0
# vegetarian spicy miso                           34110  81864.0  47754.0

# %%
        # @TODO: Else, the sales item does not equal any fo the item in the menu data, therefore no match

# %%
    # @TODO: Increment the row counter by 1

# %%
# @TODO: Print total number of records in sales data

# %%
# @TODO: Write out report to a text file (won't appear on the command line output)
